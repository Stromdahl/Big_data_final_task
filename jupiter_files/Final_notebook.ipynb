# %% [markdown]
# ## Vår analys fokuserar på att hitta korrelationer kring våra dataset.
# #### Vi har försökt se till hur stor del man kan förutspå om en user kommer svara rätt på en fråga eller ej

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Läs av datasettet som tillhandahålls

# %%
train = pd.read_csv(
    './raw_data/train.csv', 
    low_memory=False,
    nrows=10_000_000,
)

# %%
questions = pd.read_csv(
    './raw_data/questions.csv', 
    low_memory=False
)

# %% [markdown]
# ### Optimerar minnet med hjälp av mindre datatyper

# %%
train = train.dropna()
train['timestamp'] = train['timestamp'].astype('int64')
train['user_id'] = train['user_id'].astype('int32')
train['content_id'] = train['content_id'].astype('int16')
train['task_container_id'] = train['task_container_id'].astype('int16')
train['user_answer'] = train['user_answer'].astype('int8')
train['answered_correctly'] = train['answered_correctly'].astype('int32')
train['prior_question_had_explanation'] = train['prior_question_had_explanation'].astype('boolean')

# %%
train.corr()
# Out:
#                                   row_id  timestamp   user_id  content_id  \
# row_id                          1.000000  -0.003198  0.999924   -0.002310
# timestamp                      -0.003198   1.000000 -0.003364    0.053272
# user_id                         0.999924  -0.003364  1.000000   -0.002333
# content_id                     -0.002310   0.053272 -0.002333    1.000000
# content_type_id                      NaN        NaN       NaN         NaN
# task_container_id               0.028774   0.413843  0.028450    0.048702
# user_answer                    -0.000018  -0.000460 -0.000027    0.012908
# answered_correctly              0.005872   0.031593  0.005766   -0.023083
# prior_question_elapsed_time    -0.002504   0.013781 -0.002584    0.152266
# prior_question_had_explanation  0.002279   0.167653  0.002300    0.037467
#
#                                 content_type_id  task_container_id  \
# row_id                                      NaN           0.028774
# timestamp                                   NaN           0.413843
# user_id                                     NaN           0.028450
# content_id                                  NaN           0.048702
# content_type_id                             NaN                NaN
# task_container_id                           NaN           1.000000
# user_answer                                 NaN           0.002253
# answered_correctly                          NaN           0.063482
# prior_question_elapsed_time                 NaN          -0.016098
# prior_question_had_explanation              NaN           0.167548
#
#                                 user_answer  answered_correctly  \
# row_id                            -0.000018            0.005872
# timestamp                         -0.000460            0.031593
# user_id                           -0.000027            0.005766
# content_id                         0.012908           -0.023083
# content_type_id                         NaN                 NaN
# task_container_id                  0.002253            0.063482
# user_answer                        1.000000            0.005886
# answered_correctly                 0.005886            1.000000
# prior_question_elapsed_time        0.014257           -0.008253
# prior_question_had_explanation    -0.011714            0.106901
#
#                                 prior_question_elapsed_time  \
# row_id                                            -0.002504
# timestamp                                          0.013781
# user_id                                           -0.002584
# content_id                                         0.152266
# content_type_id                                         NaN
# task_container_id                                 -0.016098
# user_answer                                        0.014257
# answered_correctly                                -0.008253
# prior_question_elapsed_time                        1.000000
# prior_question_had_explanation                    -0.000534
#
#                                 prior_question_had_explanation
# row_id                                                0.002279
# timestamp                                             0.167653
# user_id                                               0.002300
# content_id                                            0.037467
# content_type_id                                            NaN
# task_container_id                                     0.167548
# user_answer                                          -0.011714
# answered_correctly                                    0.106901
# prior_question_elapsed_time                          -0.000534
# prior_question_had_explanation                        1.000000

# %% [markdown]
# ### Delar upp datasettet

# %%
features = train.iloc[:int(9/10 * len(train))]
train = train.iloc[int(9/10 * len(train)):]

# %% [markdown]
# ### Vi börjar med att ta bort 'lectures' (answered_correctly == 0 eller 1 betyder question, answered_correctly == -1 betyder lecture)
# ### Sedan grupperar vi (agg) mean, count, standardvalue, median och avvikelse för användar-id.
# ### Sedan skapar vi motsvarande kolumner för dessa värden.

# %%
train_questions_only_df = features[features['answered_correctly'] != -1]

# %% [markdown]
# ### Vi tar bort lectures för att kunna fokusera på questions villket leder till att korelationen ökar mellan timestamp och part (från 0.007 till 0.023)

# %% [markdown]
# ### Lägger till part från questions datasettet

# %%
train = pd.merge(train, questions[['question_id', 'part']], how='left', left_on=['content_id'], right_on=['question_id'])
train['part'] = train['part'].astype('int16')
train = train.drop(columns=['question_id'])
train.head()
# Out:
#     row_id  timestamp    user_id  content_id  content_type_id  \
# 0  9000814  101829438  196145707        8998                0
# 1  9000815  102282621  196145707        5264                0
# 2  9000816  102558854  196145707        5335                0
# 3  9000817  106434960  196145707        6451                0
# 4  9000818  106516904  196145707        9640                0
#
#    task_container_id  user_answer  answered_correctly  \
# 0                102            0                   1
# 1                103            1                   1
# 2                104            0                   0
# 3                105            0                   1
# 4                106            0                   0
#
#    prior_question_elapsed_time  prior_question_had_explanation  part
# 0                      18000.0                            True     5
# 1                      17000.0                            True     5
# 2                      30000.0                            True     5
# 3                      61000.0                            True     5
# 4                      30000.0                            True     5

# %%
train.corr()
# Out:
#                                   row_id  timestamp   user_id  content_id  \
# row_id                          1.000000  -0.072921  0.998625   -0.018531
# timestamp                      -0.072921   1.000000 -0.073136    0.074790
# user_id                         0.998625  -0.073136  1.000000   -0.017751
# content_id                     -0.018531   0.074790 -0.017751    1.000000
# content_type_id                      NaN        NaN       NaN         NaN
# task_container_id              -0.037652   0.423184 -0.038735    0.040718
# user_answer                     0.000474  -0.000091  0.000507    0.014730
# answered_correctly              0.003389   0.039285  0.003053   -0.030344
# prior_question_elapsed_time    -0.000729  -0.010480 -0.000161    0.146809
# prior_question_had_explanation  0.008009   0.147883  0.007533    0.032563
# part                           -0.006534   0.025467 -0.005982    0.547582
#
#                                 content_type_id  task_container_id  \
# row_id                                      NaN          -0.037652
# timestamp                                   NaN           0.423184
# user_id                                     NaN          -0.038735
# content_id                                  NaN           0.040718
# content_type_id                             NaN                NaN
# task_container_id                           NaN           1.000000
# user_answer                                 NaN           0.001041
# answered_correctly                          NaN           0.074590
# prior_question_elapsed_time                 NaN          -0.030690
# prior_question_had_explanation              NaN           0.158055
# part                                        NaN          -0.017308
#
#                                 user_answer  answered_correctly  \
# row_id                             0.000474            0.003389
# timestamp                         -0.000091            0.039285
# user_id                            0.000507            0.003053
# content_id                         0.014730           -0.030344
# content_type_id                         NaN                 NaN
# task_container_id                  0.001041            0.074590
# user_answer                        1.000000            0.006648
# answered_correctly                 0.006648            1.000000
# prior_question_elapsed_time        0.013884           -0.013716
# prior_question_had_explanation    -0.012570            0.110825
# part                               0.031107           -0.085701
#
#                                 prior_question_elapsed_time  \
# row_id                                            -0.000729
# timestamp                                         -0.010480
# user_id                                           -0.000161
# content_id                                         0.146809
# content_type_id                                         NaN
# task_container_id                                 -0.030690
# user_answer                                        0.013884
# answered_correctly                                -0.013716
# prior_question_elapsed_time                        1.000000
# prior_question_had_explanation                    -0.006678
# part                                               0.238841
#
#                                 prior_question_had_explanation      part
# row_id                                                0.008009 -0.006534
# timestamp                                             0.147883  0.025467
# user_id                                               0.007533 -0.005982
# content_id                                            0.032563  0.547582
# content_type_id                                            NaN       NaN
# task_container_id                                     0.158055 -0.017308
# user_answer                                          -0.012570  0.031107
# answered_correctly                                    0.110825 -0.085701
# prior_question_elapsed_time                          -0.006678  0.238841
# prior_question_had_explanation                        1.000000 -0.039081
# part                                                 -0.039081  1.000000

# %%
train_questions_only_df = features[features['answered_correctly'] != -1]
grouped_by_user_df = train_questions_only_df.groupby('user_id')

user_answers_df = grouped_by_user_df.agg(
    {
        'answered_correctly': [
            'mean', 
            'count', 
            'std', 
            'median', 
            'skew'
        ]
    }
).copy()

user_answers_df.columns = [
    'mean_user_accuracy', 
    'questions_answered', 
    'std_user_accuracy', 
    'median_user_accuracy', 
    'skew_user_accuracy'
]

user_answers_df.head()
# Out:
#          mean_user_accuracy  questions_answered  std_user_accuracy  \
# user_id
# 115                0.688889                  45           0.468179
# 124                0.206897                  29           0.412251
# 2746               0.611111                  18           0.501631
# 5382               0.669355                 124           0.472354
# 8623               0.638889                 108           0.482562
#
#          median_user_accuracy  skew_user_accuracy
# user_id
# 115                       1.0           -0.844439
# 124                       0.0            1.527297
# 2746                      1.0           -0.498374
# 5382                      1.0           -0.728823
# 8623                      1.0           -0.586492

# %% [markdown]
# ### Vi grupperar content-id
# ### Sedan grupperar vi (agg) mean, count, standardvalue, median, avvikelse för content-id.
# ### Sedan skapar vi motsvarande kolumner för dessa värden.

# %%
grouped_by_content_df = train_questions_only_df.groupby('content_id')
content_answers_df = grouped_by_content_df.agg(
    {
        'answered_correctly': [
            'mean', 
            'count', 
            'std', 
            'median', 
            'skew'
        ]
    }
).copy()

content_answers_df.columns = [
    'mean_accuracy', 
    'question_asked', 
    'std_accuracy', 
    'median_accuracy', 
    'skew_accuracy'
]

content_answers_df.head()
# Out:
#             mean_accuracy  question_asked  std_accuracy  median_accuracy  \
# content_id
# 0                0.901431             629      0.298320              1.0
# 1                0.889571             652      0.313665              1.0
# 2                0.558563            4064      0.496620              1.0
# 3                0.779678            2047      0.414565              1.0
# 4                0.627244            2841      0.483623              1.0
#
#             skew_accuracy
# content_id
# 0               -2.699862
# 1               -2.491635
# 2               -0.235963
# 3               -1.350577
# 4               -0.526582

# %% [markdown]
# ### Vi deletar data för att fria upp alokerat minne

# %%
del features
del grouped_by_user_df
del grouped_by_content_df

# %% [markdown]
# ### Vi skapar nya Features och en ny Target som våran algoritm ska jobba med.

# %%
features = [
    'mean_user_accuracy', 
    'questions_answered',
    'std_user_accuracy', 
    'median_user_accuracy',
    'skew_user_accuracy',
    'mean_accuracy', 
    'question_asked',
    'std_accuracy', 
    'median_accuracy',
    'prior_question_had_explanation',
    'skew_accuracy'
]

target = 'answered_correctly'

# %% [markdown]
# ### Kontrollerar att vi inte har några -1 värden i target. (Då är det lectures)

# %%
train = train[train[target] != -1]

# %% [markdown]
# ### Vi mergar user_answers och content_answers dataframes.
# ### Det förekommer nullvärden efter våran merge, så vi fyller dom.

# %%
train = train.merge(user_answers_df, how='left', on='user_id')
train = train.merge(content_answers_df, how='left', on='content_id')
fmean = train.mean()
fmean['prior_question_had_explanation'] = round(fmean['prior_question_had_explanation'])
train = train.fillna(fmean)
train.isna().sum()
# Out:
# row_id                            0
# timestamp                         0
# user_id                           0
# content_id                        0
# content_type_id                   0
# task_container_id                 0
# user_answer                       0
# answered_correctly                0
# prior_question_elapsed_time       0
# prior_question_had_explanation    0
# part                              0
# mean_user_accuracy                0
# questions_answered                0
# std_user_accuracy                 0
# median_user_accuracy              0
# skew_user_accuracy                0
# mean_accuracy                     0
# question_asked                    0
# std_accuracy                      0
# median_accuracy                   0
# skew_accuracy                     0
# dtype: int64

# %% [markdown]
# ### Vi delar dataframen i den datan som ska bearbetas (x) och (y) som i sin tur ska motsvara förutsägelse av 'answered_correctly'

# %%
X = train[features] 
y = train[target]

# %% [markdown]
# ### Vi splittar vårat data för våra algoritmer

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Vi använder oss utav 'LogisticRegression', vi ger den datan att behandla
# ### Och skriver ut det förutsatta resultatet av 'answered_correctly'

# %%
classifier = LogisticRegression()
classifier.fit(X_train, y_train.values.ravel())
print('LogisticRegression:', classifier.score(X_test, y_test))
# Out:
# LogisticRegression: 0.7118416695965619

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Vi använder oss utav 'DecisionTreeClassifier', vi ger den datan att behandla
# ### Och skriver ut det förutsatta resultatet av 'answered_correctly'

# %%
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train.values.ravel())
print('Decision Tree Result:', classifier.score(X_test, y_test))
# Out:
# Decision Tree Result: 0.7061548281829757

# %%
from sklearn.svm import SVC

# %% [markdown]
# ### Vi använder oss utav 'SVC', vi ger den datan att behandla
# ### Och skriver ut det förutsatta resultatet av 'answered_correctly'

# %%
classifier = SVC()
classifier.fit(X_train, y_train.values.ravel())
print('SVC Result:', classifier.score(X_test, y_test))

# %%
train.head()
